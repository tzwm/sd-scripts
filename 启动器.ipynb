# %% [markdown]
# ## 说明
#
# ![](https://oss.talesofai.cn/public/s_2023-04-13%20at%2022.28.22.png?cc0429)
# - 启动和重启 webui 点上方工具栏中的「重启并运行所有单元格」。出现 `http://127.0.0.1:6006` 这个字样就算成功了。可以去 autodl 控制台打开「自定义服务」了。出现「OSError: Port 6006 is in use」，就再点一次
# - 首次启动需要下载基本的模型，请稍等几分钟
# - 镜像在 A5000, 3090, 3080 上测试没问题
# - 下载模型可以本地下载好后，上传到 `~/autodl-tmp/models` 里的对应目录下。通过左边的文件管理就可以进入并上传
# - 重启可以直接在 webui 界面上重启
#
# ## 功能介绍
#
# - AUTOMATIC1111/stable-diffusion-webui \[2023-05-02\]
# - Python 3.10.6 + Torch 2.0.0 + cuda 11.8 + xformers 0.0.17
# - ControlNet v1.1 所有 model
# - 常用功能的 model 都已经下载好，包括各种 upscale、controlnet Preprocessor、CLIP 等
# - 常用的插件，包括 tagcomplete、image browser、system-info、two shot、regional prompter
# - 包含一个常用的 VAE
# - 调整了 model 目录，用数据盘来存放各种 model 防止很快就空间不足
# - git 配置了学术资源加速
# - 调整了默认配置，支持 multiple ControlNet、增加了 ControlNet 缓存 model 数量等
#
# ## 有问题请联系
#
# - Email：autodl_share@tzwm.me
# - GitHub: https://github.com/tzwm/autodl-sd-webui
# - 微信群：
#
# ![](https://oss.talesofai.cn/public/qrcode_20230413-183818.png?cc0429)
#
#
# ## ChangeLog
#
# - 20230507 第三版完成
#   - A1111 版本更新，升级 python, torch 等版本，换上 controlnet v1.1，一些细节优化
# - 20230429 第二版完成
#   - 换成 vlad webui，换上了 controlnet v1.1，更新了模型下载方式等
# - 20230413 第一版

# %%
# 初始化
# !bash /root/tzwm_sd_webui_scripts/scripts/init-download.sh
# !bash /root/tzwm_sd_webui_scripts/scripts/init-config.sh
# Out:
# 首次使用需要下载一些基本的模型，应该挺快的，稍等一下
# >>> download to  /root/autodl-tmp/models/StableDiffusion-checkpoints/anything-v4.5-pruned-fp16.ckpt
# downloading file [StableDiffusion-checkpoints/anything-v4.5-pruned-fp16.ckpt]
# downloading... 100% 2.0 GiB/2.0 GiBiB
# >>> download to  /root/autodl-tmp/models/StableDiffusion-VAE/anything-v4.0.vae.pt
# downloading file [StableDiffusion-VAE/anything-v4.0.vae.pt]
# downloading... 100% 785 MiB/785 MiBiB
# >>> download to  /root/autodl-tmp/models/StableDiffusion-LoRAs/makimaChainsawMan_offset.safetensors
# downloading file [StableDiffusion-LoRAs/makimaChainsawMan_offset.safetensors]
# downloading... 100% 144 MiB/144 MiB
# >>> download to  /root/autodl-tmp/models/StableDiffusion-Embeddings/easy_negative.safetensors
# downloading file [StableDiffusion-Embeddings/easy_negative.safetensors]
# downloading... 100% 24 KiB/24 KiB
# >>> download to  /root/autodl-tmp/models/ControlNet-v1-1
# found 29 files to download
# downloading file [ControlNet-v1-1/control_v11e_sd15_ip2p.pth]
# downloading... 100% 1.3 GiB/1.3 GiBiB
# downloading file [ControlNet-v1-1/control_v11e_sd15_ip2p.yaml]
# downloading... 100% 1.9 KiB/1.9 KiB
# downloading file [ControlNet-v1-1/control_v11e_sd15_shuffle.pth]
# downloading... 100% 1.3 GiB/1.3 GiBiB
# downloading file [ControlNet-v1-1/control_v11e_sd15_shuffle.yaml]
# downloading... 100% 1.9 KiB/1.9 KiB
# downloading file [ControlNet-v1-1/control_v11f1e_sd15_tile.pth]
# downloading... 100% 1.3 GiB/1.3 GiBiB
# downloading file [ControlNet-v1-1/control_v11f1e_sd15_tile.yaml]
# downloading... 100% 1.9 KiB/1.9 KiB
# downloading file [ControlNet-v1-1/control_v11f1p_sd15_depth.pth]
# downloading... 100% 1.3 GiB/1.3 GiBiB
# downloading file [ControlNet-v1-1/control_v11f1p_sd15_depth.yaml]
# downloading... 100% 1.9 KiB/1.9 KiB
# downloading file [ControlNet-v1-1/control_v11p_sd15_canny.pth]
# downloading... 100% 1.3 GiB/1.3 GiBiB
# downloading file [ControlNet-v1-1/control_v11p_sd15_canny.yaml]
# downloading... 100% 1.9 KiB/1.9 KiB
# downloading file [ControlNet-v1-1/control_v11p_sd15_inpaint.pth]
# downloading... 100% 1.3 GiB/1.3 GiBiBB
# downloading file [ControlNet-v1-1/control_v11p_sd15_inpaint.yaml]
# downloading... 100% 1.9 KiB/1.9 KiB
# downloading file [ControlNet-v1-1/control_v11p_sd15_lineart.pth]
# downloading... 100% 1.3 GiB/1.3 GiBiB
# downloading file [ControlNet-v1-1/control_v11p_sd15_lineart.yaml]
# downloading... 100% 1.9 KiB/1.9 KiB
# downloading file [ControlNet-v1-1/control_v11p_sd15_mlsd.pth]
# downloading... 100% 1.3 GiB/1.3 GiBiB
# downloading file [ControlNet-v1-1/control_v11p_sd15_mlsd.yaml]
# downloading... 100% 1.9 KiB/1.9 KiB
# downloading file [ControlNet-v1-1/control_v11p_sd15_normalbae.pth]
# downloading... 100% 1.3 GiB/1.3 GiBiB
# downloading file [ControlNet-v1-1/control_v11p_sd15_normalbae.yaml]
# downloading... 100% 1.9 KiB/1.9 KiB
# downloading file [ControlNet-v1-1/control_v11p_sd15_openpose.pth]
# downloading... 100% 1.3 GiB/1.3 GiBiBB
# downloading file [ControlNet-v1-1/control_v11p_sd15_openpose.yaml]
# downloading... 100% 1.9 KiB/1.9 KiB
# downloading file [ControlNet-v1-1/control_v11p_sd15_scribble.pth]
# downloading... 100% 1.3 GiB/1.3 GiBiBB
# downloading file [ControlNet-v1-1/control_v11p_sd15_scribble.yaml]
# downloading... 100% 1.9 KiB/1.9 KiB
# downloading file [ControlNet-v1-1/control_v11p_sd15_seg.pth]
# downloading... 100% 1.3 GiB/1.3 GiBiB
# downloading file [ControlNet-v1-1/control_v11p_sd15_seg.yaml]
# downloading... 100% 1.9 KiB/1.9 KiB
# downloading file [ControlNet-v1-1/control_v11p_sd15_softedge.pth]
# downloading... 100% 1.3 GiB/1.3 GiBiBB
# downloading file [ControlNet-v1-1/control_v11p_sd15_softedge.yaml]
# downloading... 100% 1.9 KiB/1.9 KiB
# downloading file [ControlNet-v1-1/control_v11p_sd15s2_lineart_anime.pth]
# downloading... 100% 1.3 GiB/1.3 GiBiB
# downloading file [ControlNet-v1-1/control_v11p_sd15s2_lineart_anime.yaml]
# downloading... 100% 1.9 KiB/1.9 KiB
# downloading file [ControlNet-v1-1/README.md]
# downloading... 100% 230 B/230 B
# 都下载好了，可以去启动了
# git 科学加速启动

# %%
# 启动
# !bash /root/tzwm_sd_webui_scripts/scripts/restart-webui.sh
# Out:
# 重启中，需要等待几秒……
#
# Usage:
#  kill [options] <pid> [...]
#
# Options:
#  <pid> [...]            send signal to every <pid> listed
#  -<signal>, -s, --signal <signal>
#                         specify the <signal> to be sent
#  -l, --list=[<signal>]  list all signal names, or convert one to a name
#  -L, --table            list all signal names in a nice table
#
#  -h, --help     display this help and exit
#  -V, --version  output version information and exit
#
# For more details see kill(1).
#
# ################################################################
# Install script for stable-diffusion + Web UI
# Tested on Debian 11 (Bullseye)
# ################################################################
#
# ################################################################
# Running on root user
# ################################################################
#
# ################################################################
# Repo already cloned, using it as install directory
# ################################################################
#
# ################################################################
# Create and activate python venv
# ################################################################
#
# ################################################################
# Launching launch.py...
# ################################################################
# Cannot locate TCMalloc (improves CPU memory usage)
# Python 3.10.6 (main, Oct 24 2022, 16:07:47) [GCC 11.2.0]
# Commit hash: 5ab7f213bec2f816f9c5644becb32eb72c8ffb89
#
#
#
# Launching Web UI with arguments: -f --no-half-vae --port 6006 --enable-insecure-extension-access --api --xformers --ckpt-dir /root/autodl-tmp/models/ckpt --embeddings-dir /root/autodl-tmp/models/embeddings --lora-dir /root/autodl-tmp/models/lora --vae-dir /root/autodl-tmp/models/vae --controlnet-dir /root/autodl-tmp/models/controlnet --skip-torch-cuda-test --skip-version-check --skip-python-version-check --skip-install
# ControlNet v1.1.146
# ControlNet v1.1.146
# Image Browser: ImageReward is not installed, cannot be used.
# Checkpoint anything-v4.5-pruned-fp16.ckpt [f773383dbc] not found; loading fallback anything-v4.5-pruned-fp16.ckpt
# Calculating sha256 for /root/autodl-tmp/models/ckpt/anything-v4.5-pruned-fp16.ckpt: f773383dbc00da6d5ee2779e8242cc3e03aca22bd1520d67eed26f95b62a343f
# Loading weights [f773383dbc] from /root/autodl-tmp/models/ckpt/anything-v4.5-pruned-fp16.ckpt
# Creating model from config: /root/stable-diffusion-webui/configs/v1-inference.yaml
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Loading VAE weights specified in settings: /root/autodl-tmp/models/vae/anything-v4.0.vae.pt
# Applying xformers cross attention optimization.
# Textual inversion embeddings loaded(1): easy_negative
# Model loaded in 11.6s (calculate hash: 6.2s, load weights from disk: 1.3s, create model: 0.5s, apply weights to model: 0.6s, apply half(): 0.4s, load VAE: 2.2s, move model to device: 0.4s).
# Running on local URL:  http://127.0.0.1:6006
#
# To create a public link, set `share=True` in `launch()`.
# Startup time: 17.7s (import torch: 1.2s, import gradio: 0.8s, import ldm: 1.1s, other imports: 0.7s, load scripts: 0.9s, load SD checkpoint: 11.7s, create ui: 1.0s, gradio launch: 0.2s).
# ['1girl, ']
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#   5%|██▏                                         | 1/20 [00:01<00:26,  1.42s/it]
#  25%|███████████                                 | 5/20 [00:01<00:03,  4.38it/s]
#  35%|███████████████▍                            | 7/20 [00:01<00:02,  6.46it/s]
#  45%|███████████████████▊                        | 9/20 [00:01<00:01,  8.51it/s]
#  55%|███████████████████████▋                   | 11/20 [00:01<00:00, 10.47it/s]
#  65%|███████████████████████████▉               | 13/20 [00:02<00:00, 12.21it/s]
#  75%|████████████████████████████████▎          | 15/20 [00:02<00:00, 13.54it/s]
#  85%|████████████████████████████████████▌      | 17/20 [00:02<00:00, 14.69it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:02<00:00,  8.08it/s]
#
# Total progress: 100%|███████████████████████████| 20/20 [00:01<00:00, 14.99it/s]
# Saving backup of webui/extension state to /root/stable-diffusion-webui/config_states/2023_05_07-22_19_19_Backup (pre-update).json.
# Closing server running on port: 6006
# Restarting UI...
# ControlNet v1.1.147
# Image Browser: ImageReward is not installed, cannot be used.
# Running on local URL:  http://127.0.0.1:6006
#
# To create a public link, set `share=True` in `launch()`.
# Startup time: 1.8s (load scripts: 0.5s, create ui: 1.0s, gradio launch: 0.2s).
